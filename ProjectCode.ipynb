# %%
import pandas as pd

#Dataset obtained from: https://www.kaggle.com/datasets/airbnb/bostonS

file_path = r"C:\Users\eliea\Desktop\UofTYear3\Term_2\Eco225\ECO225Project\Data\listings.csv"

df_listings = pd.read_csv(file_path).set_index('id')

df_caleandar = pd.read_csv(r"C:\Users\eliea\Desktop\UofTYear3\Term_2\Eco225\ECO225Project\Data\calendar.csv")

df_caleandar.rename(columns={'listing_id':'id'}, inplace=True)

df_caleandar.set_index('id')

df_caleandar.drop(columns=['price'], inplace=True)

df_cal_lis = pd.merge(df_listings, df_caleandar, on='id', how='outer')

df_cal_lis
# Out:
#                id                            listing_url       scrape_id  \
# 0            3353      https://www.airbnb.com/rooms/3353  20160906204935
# 1            3353      https://www.airbnb.com/rooms/3353  20160906204935
# 2            3353      https://www.airbnb.com/rooms/3353  20160906204935
# 3            3353      https://www.airbnb.com/rooms/3353  20160906204935
# 4            3353      https://www.airbnb.com/rooms/3353  20160906204935
# ...           ...                                    ...             ...
# 1308885  14933461  https://www.airbnb.com/rooms/14933461  20160906204935
# 1308886  14933461  https://www.airbnb.com/rooms/14933461  20160906204935
# 1308887  14933461  https://www.airbnb.com/rooms/14933461  20160906204935
# 1308888  14933461  https://www.airbnb.com/rooms/14933461  20160906204935
# 1308889  14933461  https://www.airbnb.com/rooms/14933461  20160906204935
#
#         last_scraped                                name  \
# ...
